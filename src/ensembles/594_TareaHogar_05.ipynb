# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanma300102/labo2025v/blob/main/src/ensembles/594_TareaHogar_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 05

# %% [markdown]
# Esta Tarea para el Hogar 05 se entrega el final de la cuarta clase
# <br> se espera de usted que intente avanzar con los desafios propuestos y que los traiga terminados para la Clase 05 que será el miercoles 03 de septiembre

# %% [markdown]
# ##  1. Overfitting the Public Leaderboard

# %% [markdown]
# Leer  https://medium.com/hmif-itb/overfitting-the-leaderboard-da25172ac62e
# ( 8 minutos )

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# * https://machinelearningmastery.com/light-gradient-boosted-machine-lightgbm-ensemble/
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/labo1"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/labo1" /content/buckets/b1

mkdir -p ~/.kaggle
cp /content/buckets/b1/kaggle/kaggle.json  ~/.kaggle
chmod 600 ~/.kaggle/kaggle.json


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/austral2025-af91/dataset_pequeno.csv"
archivo_destino="/content/datasets/dataset_pequeno.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/dataset_pequeno.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Thu Nov 06 11:45:47 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb) max used (Mb)
# Ncells  660443 35.3 1454477    77.7 1438389  76.9
# Vcells 1226662  9.4 8388608    64.0 1975136  15.1

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: data.table
#
# Loading required package: parallel
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 5941
PARAM$semilla_primigenia <- 101111

# %%
PARAM$kaggle$competencia <- "labo-i-2025-virtual-analista-sr"
PARAM$kaggle$cortes <- seq(10000, 12000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.5

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= FALSE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 0.8, # 0.0 < neg_bagging_fraction <= 1.0
  bagging_freq = 5,
  is_unbalance= TRUE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeNumericParam("bagging_fraction", lower=0.1, upper=1.0),
  makeIntegerParam("num_iterations", lower= 8L, upper= 2048L),
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.3),
  makeNumericParam("feature_fraction", lower= 0.1, upper= 1.0),
  makeIntegerParam("num_leaves", lower= 8L, upper= 2048L),
  makeIntegerParam("min_data_in_leaf", lower= 1L, upper= 8000L),
  makeIntegerParam("n_estimators", lower=1000L, upper=10000L)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 30 # iteraciones bayesianas

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset

dataset <- fread("/content/datasets/dataset_pequeno.csv")

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in% c(202107) &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 83225
# [1] 154

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Fri Nov 07 12:18:26 AM 2025 AUC 0.922682029824442
#
# Fri Nov 07 12:20:48 AM 2025 AUC 0.92455403436446
#
# Fri Nov 07 12:23:55 AM 2025 AUC 0.920944331984289
#
# Fri Nov 07 12:25:36 AM 2025 AUC 0.921400427696312
#
# Fri Nov 07 12:29:13 AM 2025 AUC 0.926304670971924
#
# Fri Nov 07 12:30:15 AM 2025 AUC 0.924461318461456
#
# Fri Nov 07 12:34:11 AM 2025 AUC 0.921778424869854
#
# Fri Nov 07 12:38:42 AM 2025 AUC 0.921995690622143
#
# Fri Nov 07 12:44:35 AM 2025 AUC 0.922325846658588
#
# Fri Nov 07 12:45:44 AM 2025 AUC 0.924694157550049
#
# Fri Nov 07 12:52:05 AM 2025 AUC 0.925777279036037
#
# Fri Nov 07 12:54:27 AM 2025 AUC 0.922876159114525
#
# Fri Nov 07 12:56:37 AM 2025 AUC 0.924979492623895
#
# Fri Nov 07 12:57:02 AM 2025 AUC 0.922592333510351
#
# Fri Nov 07 01:03:20 AM 2025 AUC 0.926775491125667
#
# Fri Nov 07 01:06:12 AM 2025 AUC 0.92675476716598
#
# Fri Nov 07 01:06:56 AM 2025 AUC 0.924447129861692
#
# Fri Nov 07 01:06:59 AM 2025 AUC 0.908102460068301
#
# Fri Nov 07 01:12:04 AM 2025 AUC 0.92221451332572
#
# Fri Nov 07 01:16:02 AM 2025 AUC 0.920538356000749
#
# Fri Nov 07 01:16:28 AM 2025 AUC 0.91710530190232
#
# Fri Nov 07 01:18:18 AM 2025 AUC 0.921270656420428
#
# Fri Nov 07 01:23:54 AM 2025 AUC 0.918369277592769
#
# Fri Nov 07 01:28:53 AM 2025 AUC 0.919041720151848
#
# Fri Nov 07 01:35:25 AM 2025 AUC 0.921848504405285
#
# Fri Nov 07 01:38:52 AM 2025 AUC 0.922570118324909
#
# Fri Nov 07 01:45:25 AM 2025 AUC 0.926643900471902
#
# Fri Nov 07 01:47:02 AM 2025 AUC 0.92149247637903
#
# [mbo] 0: bagging_fraction=0.77; num_iterations=1328; learning_rate=0.226; feature_fraction=0.764; num_leaves=935; min_data_in_leaf=3927; n_estimators=5551 : y = 0.923 : 204.9 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.445; num_iterations=578; learning_rate=0.156; feature_fraction=0.514; num_leaves=1364; min_data_in_leaf=2628; n_estimators=7555 : y = 0.925 : 142.1 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.279; num_iterations=1046; learning_rate=0.236; feature_fraction=0.29; num_leaves=1532; min_data_in_leaf=6352; n_estimators=5483 : y = 0.921 : 187.1 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.342; num_iterations=614; learning_rate=0.12; feature_fraction=0.201; num_leaves=583; min_data_in_leaf=6953; n_estimators=6046 : y = 0.921 : 101.1 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.552; num_iterations=1105; learning_rate=0.069; feature_fraction=0.739; num_leaves=1404; min_data_in_leaf=1629; n_estimators=3806 : y = 0.926 : 216.5 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.509; num_iterations=421; learning_rate=0.0431; feature_fraction=0.857; num_leaves=1266; min_data_in_leaf=4864; n_estimators=4337 : y = 0.924 : 62.7 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.657; num_iterations=1004; learning_rate=0.26; feature_fraction=0.528; num_leaves=847; min_data_in_leaf=2990; n_estimators=1807 : y = 0.922 : 235.8 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.811; num_iterations=1830; learning_rate=0.0995; feature_fraction=0.114; num_leaves=275; min_data_in_leaf=5584; n_estimators=8610 : y = 0.922 : 270.8 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.616; num_iterations=1686; learning_rate=0.137; feature_fraction=0.469; num_leaves=1724; min_data_in_leaf=6278; n_estimators=7106 : y = 0.922 : 353.0 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.883; num_iterations=333; learning_rate=0.174; feature_fraction=0.322; num_leaves=794; min_data_in_leaf=3499; n_estimators=4552 : y = 0.925 : 68.6 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.716; num_iterations=1540; learning_rate=0.204; feature_fraction=0.796; num_leaves=1886; min_data_in_leaf=777; n_estimators=1154 : y = 0.926 : 381.3 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.101; num_iterations=725; learning_rate=0.104; feature_fraction=0.56; num_leaves=1221; min_data_in_leaf=7434; n_estimators=6447 : y = 0.923 : 142.1 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.953; num_iterations=839; learning_rate=0.127; feature_fraction=0.632; num_leaves=1125; min_data_in_leaf=4739; n_estimators=9517 : y = 0.925 : 129.9 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.247; num_iterations=109; learning_rate=0.207; feature_fraction=0.248; num_leaves=1064; min_data_in_leaf=3237; n_estimators=3299 : y = 0.923 : 24.6 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.303; num_iterations=1457; learning_rate=0.145; feature_fraction=0.331; num_leaves=319; min_data_in_leaf=894; n_estimators=6554 : y = 0.927 : 378.1 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.548; num_iterations=924; learning_rate=0.0125; feature_fraction=0.878; num_leaves=129; min_data_in_leaf=2086; n_estimators=5100 : y = 0.927 : 172.4 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.796; num_iterations=229; learning_rate=0.184; feature_fraction=0.837; num_leaves=23; min_data_in_leaf=1771; n_estimators=3987 : y = 0.924 : 44.0 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.391; num_iterations=10; learning_rate=0.035; feature_fraction=0.583; num_leaves=1950; min_data_in_leaf=1158; n_estimators=8333 : y = 0.908 : 3.2 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.59; num_iterations=2009; learning_rate=0.273; feature_fraction=0.687; num_leaves=217; min_data_in_leaf=4088; n_estimators=8926 : y = 0.922 : 305.0 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.985; num_iterations=1520; learning_rate=0.188; feature_fraction=0.181; num_leaves=488; min_data_in_leaf=6700; n_estimators=3031 : y = 0.921 : 237.9 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.176; num_iterations=167; learning_rate=0.0211; feature_fraction=0.95; num_leaves=443; min_data_in_leaf=4434; n_estimators=9888 : y = 0.917 : 26.0 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.388; num_iterations=756; learning_rate=0.282; feature_fraction=0.673; num_leaves=1610; min_data_in_leaf=5336; n_estimators=1418 : y = 0.921 : 110.0 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.68; num_iterations=1871; learning_rate=0.299; feature_fraction=0.156; num_leaves=1764; min_data_in_leaf=2398; n_estimators=7868 : y = 0.918 : 335.5 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.148; num_iterations=1284; learning_rate=0.238; feature_fraction=0.983; num_leaves=1639; min_data_in_leaf=110; n_estimators=7128 : y = 0.919 : 299.5 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.215; num_iterations=1941; learning_rate=0.0873; feature_fraction=0.443; num_leaves=606; min_data_in_leaf=7194; n_estimators=2711 : y = 0.922 : 391.4 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.907; num_iterations=1630; learning_rate=0.0732; feature_fraction=0.918; num_leaves=2033; min_data_in_leaf=7859; n_estimators=2263 : y = 0.923 : 207.0 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.841; num_iterations=1239; learning_rate=0.0606; feature_fraction=0.377; num_leaves=1012; min_data_in_leaf=386; n_estimators=2561 : y = 0.927 : 393.6 secs : initdesign
#
# [mbo] 0: bagging_fraction=0.458; num_iterations=485; learning_rate=0.256; feature_fraction=0.397; num_leaves=694; min_data_in_leaf=5763; n_estimators=9267 : y = 0.921 : 96.8 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Fri Nov 07 01:50:47 AM 2025 AUC 0.925886624669586
#
# [mbo] 1: bagging_fraction=0.775; num_iterations=1179; learning_rate=0.122; feature_fraction=0.706; num_leaves=1291; min_data_in_leaf=1970; n_estimators=2085 : y = 0.926 : 223.6 secs : infill_ei
#
# Fri Nov 07 01:58:09 AM 2025 AUC 0.926943492365429
#
# [mbo] 2: bagging_fraction=0.461; num_iterations=1393; learning_rate=0.0248; feature_fraction=0.436; num_leaves=150; min_data_in_leaf=2; n_estimators=4512 : y = 0.927 : 441.6 secs : infill_ei
#
# Saved the current state after iteration 3 in the file bayesiana.RDATA.
#
# Fri Nov 07 02:04:57 AM 2025 AUC 0.923585418496645
#
# [mbo] 3: bagging_fraction=0.576; num_iterations=1528; learning_rate=0.0914; feature_fraction=0.701; num_leaves=657; min_data_in_leaf=9; n_estimators=4005 : y = 0.924 : 406.8 secs : infill_ei
#
# Fri Nov 07 02:09:20 AM 2025 AUC 0.929265344546695
#
# [mbo] 4: bagging_fraction=0.453; num_iterations=1193; learning_rate=0.0465; feature_fraction=0.38; num_leaves=25; min_data_in_leaf=408; n_estimators=6341 : y = 0.929 : 262.6 secs : infill_ei
#
# Saved the current state after iteration 5 in the file bayesiana.RDATA.
#
# Fri Nov 07 02:12:29 AM 2025 AUC 0.926868032775083
#
# [mbo] 5: bagging_fraction=0.545; num_iterations=1023; learning_rate=0.149; feature_fraction=0.371; num_leaves=9; min_data_in_leaf=2; n_estimators=7048 : y = 0.927 : 187.7 secs : infill_ei
#
# Fri Nov 07 02:16:46 AM 2025 AUC 0.925511370045916
#
# [mbo] 6: bagging_fraction=0.104; num_iterations=1269; learning_rate=0.032; feature_fraction=0.448; num_leaves=8; min_data_in_leaf=1479; n_estimators=6480 : y = 0.926 : 256.5 secs : infill_ei
#
# Fri Nov 07 02:19:33 AM 2025 AUC 0.927556749104865
#
# [mbo] 7: bagging_fraction=0.75; num_iterations=1130; learning_rate=0.0432; feature_fraction=0.139; num_leaves=9; min_data_in_leaf=285; n_estimators=7030 : y = 0.928 : 165.9 secs : infill_ei
#
# Saved the current state after iteration 8 in the file bayesiana.RDATA.
#
# Fri Nov 07 02:23:53 AM 2025 AUC 0.927497269506456
#
# [mbo] 8: bagging_fraction=0.483; num_iterations=1160; learning_rate=0.0681; feature_fraction=0.317; num_leaves=31; min_data_in_leaf=788; n_estimators=4680 : y = 0.927 : 259.3 secs : infill_ei
#
# Fri Nov 07 02:31:33 AM 2025 AUC 0.929984902740497
#
# [mbo] 9: bagging_fraction=0.505; num_iterations=1204; learning_rate=0.0183; feature_fraction=0.45; num_leaves=239; min_data_in_leaf=239; n_estimators=7831 : y = 0.93 : 459.0 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana.RDATA.
#
# Fri Nov 07 02:36:52 AM 2025 AUC 0.929327594862039
#
# [mbo] 10: bagging_fraction=0.464; num_iterations=1208; learning_rate=0.0204; feature_fraction=0.216; num_leaves=524; min_data_in_leaf=388; n_estimators=7164 : y = 0.929 : 317.8 secs : infill_ei
#
# Fri Nov 07 02:41:51 AM 2025 AUC 0.92813637775037
#
# [mbo] 11: bagging_fraction=0.456; num_iterations=1211; learning_rate=0.0384; feature_fraction=0.591; num_leaves=58; min_data_in_leaf=1322; n_estimators=9911 : y = 0.928 : 298.5 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Fri Nov 07 02:53:46 AM 2025 AUC 0.92692385608605
#
# [mbo] 12: bagging_fraction=0.625; num_iterations=1141; learning_rate=0.0168; feature_fraction=0.421; num_leaves=862; min_data_in_leaf=45; n_estimators=7869 : y = 0.927 : 714.6 secs : infill_ei
#
# Saved the current state after iteration 13 in the file bayesiana.RDATA.
#
# Fri Nov 07 02:58:31 AM 2025 AUC 0.928725795004073
#
# [mbo] 13: bagging_fraction=0.474; num_iterations=1304; learning_rate=0.0513; feature_fraction=0.196; num_leaves=60; min_data_in_leaf=296; n_estimators=7825 : y = 0.929 : 283.6 secs : infill_ei
#
# Fri Nov 07 03:04:31 AM 2025 AUC 0.928887781986934
#
# [mbo] 14: bagging_fraction=0.38; num_iterations=1170; learning_rate=0.0107; feature_fraction=0.259; num_leaves=222; min_data_in_leaf=269; n_estimators=9549 : y = 0.929 : 359.3 secs : infill_ei
#
# Saved the current state after iteration 15 in the file bayesiana.RDATA.
#
# Fri Nov 07 03:07:33 AM 2025 AUC 0.92754402850101
#
# [mbo] 15: bagging_fraction=0.887; num_iterations=691; learning_rate=0.0869; feature_fraction=0.982; num_leaves=1421; min_data_in_leaf=742; n_estimators=2225 : y = 0.928 : 181.3 secs : infill_ei
#
# Fri Nov 07 03:09:21 AM 2025 AUC 0.92454373588907
#
# [mbo] 16: bagging_fraction=0.924; num_iterations=699; learning_rate=0.058; feature_fraction=0.959; num_leaves=29; min_data_in_leaf=3756; n_estimators=1861 : y = 0.925 : 107.5 secs : infill_ei
#
# Fri Nov 07 03:11:39 AM 2025 AUC 0.925691005853586
#
# [mbo] 17: bagging_fraction=0.909; num_iterations=841; learning_rate=0.0301; feature_fraction=0.949; num_leaves=2043; min_data_in_leaf=3273; n_estimators=2308 : y = 0.926 : 137.7 secs : infill_ei
#
# Fri Nov 07 03:17:13 AM 2025 AUC 0.922045805855727
#
# [mbo] 18: bagging_fraction=0.553; num_iterations=830; learning_rate=0.0746; feature_fraction=0.902; num_leaves=380; min_data_in_leaf=66; n_estimators=5687 : y = 0.922 : 333.6 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Fri Nov 07 03:18:52 AM 2025 AUC 0.923718530682867
#
# [mbo] 19: bagging_fraction=1; num_iterations=579; learning_rate=0.12; feature_fraction=0.96; num_leaves=1534; min_data_in_leaf=2890; n_estimators=1671 : y = 0.924 : 97.4 secs : infill_ei
#
# Fri Nov 07 03:23:15 AM 2025 AUC 0.927957534987919
#
# [mbo] 20: bagging_fraction=0.73; num_iterations=1223; learning_rate=0.0102; feature_fraction=0.254; num_leaves=239; min_data_in_leaf=1487; n_estimators=6987 : y = 0.928 : 262.2 secs : infill_ei
#
# Fri Nov 07 03:27:47 AM 2025 AUC 0.927925025543497
#
# [mbo] 21: bagging_fraction=0.503; num_iterations=1096; learning_rate=0.0104; feature_fraction=0.438; num_leaves=24; min_data_in_leaf=1641; n_estimators=7243 : y = 0.928 : 272.1 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana.RDATA.
#
# Fri Nov 07 03:33:43 AM 2025 AUC 0.927670205795363
#
# [mbo] 22: bagging_fraction=0.665; num_iterations=1203; learning_rate=0.0217; feature_fraction=0.43; num_leaves=199; min_data_in_leaf=688; n_estimators=7864 : y = 0.928 : 355.3 secs : infill_ei
#
# Fri Nov 07 03:38:48 AM 2025 AUC 0.929758440204393
#
# [mbo] 23: bagging_fraction=0.426; num_iterations=1223; learning_rate=0.0112; feature_fraction=0.557; num_leaves=31; min_data_in_leaf=108; n_estimators=7355 : y = 0.93 : 303.8 secs : infill_ei
#
# Saved the current state after iteration 24 in the file bayesiana.RDATA.
#
# Fri Nov 07 03:43:07 AM 2025 AUC 0.916994832347512
#
# [mbo] 24: bagging_fraction=0.819; num_iterations=727; learning_rate=0.152; feature_fraction=0.336; num_leaves=1939; min_data_in_leaf=12; n_estimators=2092 : y = 0.917 : 258.2 secs : infill_ei
#
# Fri Nov 07 03:51:59 AM 2025 AUC 0.928398361854263
#
# [mbo] 25: bagging_fraction=0.414; num_iterations=1251; learning_rate=0.0193; feature_fraction=0.439; num_leaves=797; min_data_in_leaf=172; n_estimators=7806 : y = 0.928 : 531.4 secs : infill_ei
#
# Saved the current state after iteration 26 in the file bayesiana.RDATA.
#
# Fri Nov 07 03:55:18 AM 2025 AUC 0.92806922448434
#
# [mbo] 26: bagging_fraction=0.455; num_iterations=544; learning_rate=0.0258; feature_fraction=0.323; num_leaves=257; min_data_in_leaf=23; n_estimators=6983 : y = 0.928 : 198.6 secs : infill_ei
#
# Fri Nov 07 03:57:20 AM 2025 AUC 0.923586968392891
#
# [mbo] 27: bagging_fraction=0.743; num_iterations=638; learning_rate=0.0104; feature_fraction=0.183; num_leaves=343; min_data_in_leaf=1742; n_estimators=6506 : y = 0.924 : 120.2 secs : infill_ei
#
# Fri Nov 07 04:00:42 AM 2025 AUC 0.926517782377564
#
# [mbo] 28: bagging_fraction=0.919; num_iterations=1020; learning_rate=0.0128; feature_fraction=0.829; num_leaves=642; min_data_in_leaf=1668; n_estimators=3802 : y = 0.927 : 201.6 secs : infill_ei
#
# Fri Nov 07 04:05:45 AM 2025 AUC 0.928237069514488
#
# [mbo] 29: bagging_fraction=0.949; num_iterations=1267; learning_rate=0.0855; feature_fraction=0.852; num_leaves=1362; min_data_in_leaf=974; n_estimators=1519 : y = 0.928 : 302.6 secs : infill_ei
#
# Saved the current state after iteration 30 in the file bayesiana.RDATA.
#
# Fri Nov 07 04:07:24 AM 2025 AUC 0.926173005517236
#
# [mbo] 30: bagging_fraction=0.398; num_iterations=448; learning_rate=0.0132; feature_fraction=0.381; num_leaves=15; min_data_in_leaf=318; n_estimators=2848 : y = 0.926 : 98.0 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "bagging_fraction" "num_iterations"   "learning_rate"    "feature_fraction"
#  [5] "num_leaves"       "min_data_in_leaf" "n_estimators"     "y"
#  [9] "dob"              "eol"              "error.message"    "exec.time"
# [13] "ei"               "error.model"      "train.time"       "prop.type"
# [17] "propose.time"     "se"               "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    bagging_fraction num_iterations learning_rate feature_fraction num_leaves
#               <num>          <int>         <num>            <num>      <int>
# 1:        0.5052557           1204    0.01833636        0.4501753        239
#    min_data_in_leaf n_estimators
#               <int>        <int>
# 1:              239         7831
# [1] 0.9299849

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% c(202107)]

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
  # entreno LightGBM

  modelo_final <- lgb.train(
    data= dtrain,
    param= param_normalizado
  )

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...

lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes == 202109]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$kaggle$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marclo los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # subida a Kaggle, armo la linea de comando
  comando <- "kaggle competitions submit"
  competencia <- paste("-c", PARAM$kaggle$competencia)
  arch <- paste( "-f", archivo_kaggle)

  mensaje <- paste0("-m 'envios=", envios,
  "  semilla=", PARAM$semilla_primigenia,
    "'" )

  linea <- paste( comando, competencia, arch, mensaje)

  salida <- system(linea, intern=TRUE) # el submit a Kaggle
  cat(salida, "\n")
  Sys.sleep(45)
}

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar-05**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla

# %% [markdown]
# Seguramente usted realice varias corridas de este script con distintos conjuntos de hiperparámetros, siempre cambiandole el nombre al script  y también cambiando el nombre del experimento,  deberá TODAS esas corridas en distintas lineas de la  Google Sheet Colaborativa, hoja **TareaHogar-05**

# %% [markdown]
# Siéntase libre de agregar columnas a la hoja **TareaHogar-05**  en caso de ser necesario.
